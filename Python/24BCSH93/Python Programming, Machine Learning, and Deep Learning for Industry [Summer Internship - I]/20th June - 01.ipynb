# %% [markdown]
# Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
week = [1, 2, 3, 4, 5, 6, 7]
temp = [32, 34, 35, 36, 38, 35, 34]

# %%
plt.plot(week, temp)

# %%
plt.plot(week, temp)
plt.xlabel("days")
plt.ylabel("temp")
# Out:
# Text(0, 0.5, 'temp')

# %%
plt.plot(week, temp)
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, c="m")
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, c="m", ls=":")
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, c="#FFA500", ls=":")
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, c="#FFA500", ls=":", marker="<")
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, c="#FFA500", ls=":", marker="<", ms=20.5)
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %% [markdown]
# fmt = "[marker][line][color]"

# %%
plt.plot(week, temp, "o--g", ms=7)
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
plt.plot(week, temp, "ro:", ms=7)
plt.xlabel("days")
plt.ylabel("temp")
plt.title("Silicon Institute Weather")
# Out:
# Text(0.5, 1.0, 'Silicon Institute Weather')

# %%
days = [1, 2, 3, 4, 5, 6, 7]
max_t = [50, 51, 52, 48, 47, 49, 46]
min_t = [43, 42, 40, 44, 45, 35, 37]
avg_t = [45, 48, 48, 46, 40, 42, 41]

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.xlabel("days")
plt.ylabel("temp")
plt.title("Bhubaneswar's - weather info")
plt.legend()

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.xlabel("days")
plt.ylabel("temp")
plt.title("Bhubaneswar's - weather info")
plt.legend(loc="lower left")

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.xlabel("days")
plt.ylabel("temp")
plt.title("Bhubaneswar's - weather info")
plt.legend(loc="best")

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.xlabel("days")
plt.ylabel("temp")
plt.title("Bhubaneswar's - weather info")
plt.legend(loc=0)
plt.grid()

# %% [markdown]
# Bar Graph

# %%
company = ["Google", "MSFT", "FB", "Twitter"]
stock = [234, 344, 545, 656]

# %%
plt.bar(company, stock)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company, stock)
# Out:
# <BarContainer object of 4 artists>

# %%
blood_sugar = [113, 122, 80, 99, 112, 87, 130, 150, 88, 78, 94]

# %%
plt.hist(blood_sugar)
# Out:
# (array([2., 2., 2., 0., 2., 0., 1., 1., 0., 1.]),
#  array([ 78. ,  85.2,  92.4,  99.6, 106.8, 114. , 121.2, 128.4, 135.6,
#         142.8, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, bins=[78, 100, 125, 150])
# Out:
# (array([6., 3., 2.]),
#  array([ 78., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins=[78, 100, 125, 150], histtype="step")
# Out:
# (array([6., 3., 2.]),
#  array([ 78., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x7f8745e462c0>])

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

# %%
plt.hist([blood_sugar_men, blood_sugar_women], bins=[78, 100, 125, 150], color=["green", "orange"],
         label=["Men", "Women"])
plt.legend("men vs women")

# %% [markdown]
# Pie Chart

# %%
exp_values = [1500, 800, 300, 410, 250]
exp_labels = ["Rent", "Travel", "Mobile Bill", "Food", "Others"]

# %%
plt.pie(exp_values)
plt.show()

# %%
plt.pie(exp_values, labels=exp_labels)
plt.show()

# %%
plt.pie(exp_values, labels=exp_labels, autopct="%.1f%%")
plt.show()

# %%
plt.pie(exp_values, labels=exp_labels, autopct="%.1f%%", radius=2)
plt.show()

# %%
plt.pie(exp_values, labels=exp_labels, explode=[0, 0, 0.5, 0, 0], autopct="%.1f%%", radius=2)
plt.show()

# %%
plt.pie(exp_values, labels=exp_labels, explode=[0.1, 0.2, 0.3, 0.4, 0], autopct="%.1f%%", radius=2)
plt.show()

# %% [markdown]
# Scatter plot

# %%
years = [2020, 2021, 2022, 2023]
sales = [200, 250, 300, 350]
profits = [30, 45, 60, 80]
categories = ["A", "B", "C", "D"]
values = [10, 40, 30, 20]
data = np.random.normal(loc=50, scale=10, size=100)

# %%
plt.scatter(blood_sugar_men, blood_sugar_women)

# %%
plt.scatter(blood_sugar_men, blood_sugar_women)
plt.title("Men blood sugar v/s Women blood sugar")
plt.xlabel("Men blood sugar")
plt.ylabel("women blood sugar")
plt.grid()
plt.show()

# %%
df = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105],
    "name": ["Alice", "Bob", "Carol", "David", "Eva"],
    "sex": ["F", "M", "F", None, None],
    "state": ["MH", None, "KA", "MH", "KA"],
    "age": [25, 32, 35, 60, 22],
    "is_married": [True, False, True, True, False],
    "active_since": pd.to_datetime(["2018-05-01", "2019-07-23", "2020-01-15", "2015-12-31", "2021-06-11"]),
    "event_time": pd.to_datetime(
        ["2024-01-01 10:30", "2024-01-03 14:00", "2024-01-04 09:15", "2024-01-05 16:45", "2024-01-06 12:00"]),
    "email": ["alice@example.com", "bob@example.com", "carol@example.com", None, "eva@example.com"]
})
df
# Out:
#    customer_id   name   sex state  age  is_married active_since  \
# 0          101  Alice     F    MH   25        True   2018-05-01
# 1          102    Bob     M  None   32       False   2019-07-23
# 2          103  Carol     F    KA   35        True   2020-01-15
# 3          104  David  None    MH   60        True   2015-12-31
# 4          105    Eva  None    KA   22       False   2021-06-11
#
#            event_time              email
# 0 2024-01-01 10:30:00  alice@example.com
# 1 2024-01-03 14:00:00    bob@example.com
# 2 2024-01-04 09:15:00  carol@example.com
# 3 2024-01-05 16:45:00               None
# 4 2024-01-06 12:00:00    eva@example.com

# %%
plt.scatter(df["customer_id"], df["age"])
plt.title("Men blood sugar v/s Women blood sugar")
plt.xlabel("Men blood sugar")
plt.ylabel("women blood sugar")
plt.grid()
plt.show()
plt.savefig("scatter.jpeg")

# %% [markdown]
# Box Plot

# %%
plt.boxplot([sales, profits], labels=["sales", "profits"])
plt.title("Box plot")
plt.show()
# Out:
# /tmp/ipykernel_21500/814519892.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([sales, profits], labels=["sales", "profits"])

# %%
plt.boxplot(df["age"], labels=["age"])
plt.title("Box plot")
plt.show()
# Out:
# /tmp/ipykernel_21500/568188636.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df["age"], labels=["age"])

# %%
plt.subplot(2, 2, 1)
plt.pie(exp_values, labels=exp_labels, autopct="%.2f%%")

plt.subplot(2, 2, 4)
plt.hist([blood_sugar_men, blood_sugar_women], bins=[78, 100, 125, 150], color=["green", "orange"],
         label=["Men", "Women"])
plt.legend("men vs women")

# %%
plt.subplot(3, 3, 1)
plt.pie(exp_values, labels=exp_labels, autopct="%.2f%%")

plt.subplot(3, 3, 3)
plt.hist([blood_sugar_men, blood_sugar_women], bins=[78, 100, 125, 150], color=["green", "orange"],
         label=["Men", "Women"])

plt.subplot(3, 3, 8)
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.xlabel("days")
plt.ylabel("temp")
plt.title("Bhubaneswar's - weather info")
plt.grid()
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# Load a built-in dataset

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")
penguins = sns.load_dataset("penguins")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# histogram

# %%
sns.histplot(data=tips, x="total_bill", kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data=tips, x="tip", fill=True)
plt.title("kde plot for tips")
plt.show()

# %%
sns.boxplot(data=tips, y="total_bill")
plt.title("Box plot")
plt.show()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.violinplot(data=iris, x="species", y="sepal_length")
plt.title("violin plot")
plt.show()

# %%
sns.violinplot(data=iris, x="sepal_width", y="sepal_length")
plt.title("violin plot")
plt.show()

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(data=iris, x="sepal_length", y="petal_length", hue="species")
plt.title("scatter plot")
plt.show()

# %%
sns.pairplot(iris, hue="species")
plt.suptitle("Pair Plot of Iris", y=1.02)
plt.show()

# %%
sns.pairplot(df, hue="sex")
plt.suptitle("Pair Plot of Iris", y=1.02)
plt.show()

# %%
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

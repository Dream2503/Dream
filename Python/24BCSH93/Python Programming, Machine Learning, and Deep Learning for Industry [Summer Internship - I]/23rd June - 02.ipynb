# %% [markdown]
# ## Step A: DATA PREPROCESSING

# %% [markdown]
# #### Step 1: Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 2: Import the dataset

# %%
dataset = pd.read_csv("Logistic Data.csv")

# %%
dataset.head()
# Out:
#    Age  Salary  Purchased Plot
# 0   22   22990               0
# 1   38   24200               0
# 2   29   52030               0
# 3   30   68970               0
# 4   22   91960               0

# %% [markdown]
# #### Step 3: Do we have any missing data?

# %%
dataset.isnull().sum()
# Out:
# Age               0
# Salary            0
# Purchased Plot    0
# dtype: int64

# %% [markdown]
# ### Step B: Building classification model

# %% [markdown]
# #### Step 1: To create a feature matrix (X) and output dependent column vector (Y)

# %%
X = dataset.iloc[:, 0:2].values
Y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[    22,  22990],
#        [    38,  24200],
#        [    29,  52030],
#        [    30,  68970],
#        [    22,  91960],
#        [    30,  70180],
#        [    30, 101640],
#        [    35, 181500],
#        [    28,  39930],
#        [    38,  78650],
#        [    29,  96800],
#        [    29,  62920],
#        [    23, 104060],
#        [    35,  21780],
#        [    21,  99220],
#        [    32,  96800],
#        [    50,  30250],
#        [    48,  31460],
#        [    49,  33880],
#        [    51,  35090],
#        [    48,  26620],
#        [    50,  59290],
#        [    51,  49610],
#        [    48,  26620],
#        [    49,  27830],
#        [    50,  24200],
#        [    52,  33880],
#        [    50,  36300],
#        [    32,  52030],
#        [    34,  21780],
#        [    34,  89540],
#        [    30, 165770],
#        [    24,  19360],
#        [    31,  53240],
#        [    30, 108900],
#        [    38,  32670],
#        [    36,  33880],
#        [    33,  59290],
#        [    29,  87120],
#        [    30,  37510],
#        [    30,  20570],
#        [    36,  61710],
#        [    38, 130680],
#        [    33,  18150],
#        [    31, 101640],
#        [    26,  24200],
#        [    28,  95590],
#        [    30,  65340],
#        [    33, 163350],
#        [    34, 107690],
#        [    27,  38720],
#        [    21,  53240],
#        [    32, 100430],
#        [    38,  27830],
#        [    30,  70180],
#        [    27,  66550],
#        [    26,  58080],
#        [    31,  95590],
#        [    25,  21780],
#        [    35, 141570],
#        [    30,  24200],
#        [    28, 105270],
#        [    26,  79860],
#        [    35, 145200],
#        [    62, 100430],
#        [    27,  70180],
#        [    27,  22990],
#        [    26,  99220],
#        [    25,  76230],
#        [    34,  82280],
#        [    28,  96800],
#        [    27,  32670],
#        [    23,  27830],
#        [    36, 136730],
#        [    35,  21780],
#        [    37, 135520],
#        [    21,  62920],
#        [    25,  32670],
#        [    31, 105270],
#        [    29,  20570],
#        [    33,  96800],
#        [    42,  50820],
#        [    23,  59290],
#        [    38, 106480],
#        [    33,  75020],
#        [    34, 142780],
#        [    27,  66550],
#        [    31, 102850],
#        [    29,  98010],
#        [    38,  60500],
#        [    25,  98010],
#        [    33, 140360],
#        [    29,  18150],
#        [    32,  33880],
#        [    32, 100430],
#        [    38,  53240],
#        [    38,  30250],
#        [    31, 148830],
#        [    38,  88330],
#        [    31,  44770],
#        [    30, 106480],
#        [    31,  71390],
#        [    35, 104060],
#        [    36, 180290],
#        [    22,  25410],
#        [    24,  87120],
#        [    29,  42350],
#        [    30, 107690],
#        [    29, 104060],
#        [    41,  96800],
#        [    42,  85910],
#        [    40,  85910],
#        [    41,  73810],
#        [    40,  66550],
#        [    45,  96800],
#        [    43,  68970],
#        [    38,  90750],
#        [    39,  62920],
#        [    43,  71390],
#        [    44,  71390],
#        [    39,  90750],
#        [    40,  87120],
#        [    43,  90750],
#        [    38,  64130],
#        [    44,  61710],
#        [    42,  73810],
#        [    45,  78650],
#        [    29,  38720],
#        [    33,  20570],
#        [    29, 101640],
#        [    34,  70180],
#        [    36,  37510],
#        [    33, 105270],
#        [    24,  82280],
#        [    31,  66550],
#        [    26,  76230],
#        [    23,  99220],
#        [    33, 129470],
#        [    31,  71390],
#        [    22,  30250],
#        [    22, 102850],
#        [    21,  82280],
#        [    38,  71390],
#        [    33, 107690],
#        [    37,  30250],
#        [    27, 107690],
#        [    30, 116160],
#        [    44,  36300],
#        [    32,  73810],
#        [    23,  89540],
#        [    29,  18150],
#        [    44,  54450],
#        [    34,  91960],
#        [    39,  60500],
#        [    43,  56870],
#        [    34,  18150],
#        [    49,  71390],
#        [    32,  90750],
#        [    29,  36300],
#        [    35, 163350],
#        [    35, 121000],
#        [    28, 108900],
#        [    40,  39930],
#        [    38,  45980],
#        [    36,  83490],
#        [    21, 104060],
#        [    25,  66550],
#        [    38,  85910],
#        [    32, 179080],
#        [    32,  56870],
#        [    24, 106480],
#        [    37, 139150],
#        [    29, 142780],
#        [    37,  52030],
#        [    37,  87120],
#        [    26,  33880],
#        [    38,  56870],
#        [    28,  26620],
#        [    27,  27830],
#        [    34,  41140],
#        [    29,  19360],
#        [    34,  85910],
#        [    35, 141570],
#        [    36,  52030],
#        [    36,  72600],
#        [    34,  79860],
#        [    23,  99220],
#        [    36,  49610],
#        [    38,  87120],
#        [    31,  38720],
#        [    27, 101640],
#        [    22,  31460],
#        [    32,  52030],
#        [    22,  84700],
#        [    31, 107690],
#        [    37,  52030],
#        [    33,  95590],
#        [    23,  43560],
#        [    29,  96800],
#        [    38,  26620],
#        [    38,  47190],
#        [    52,  89540],
#        [    42, 162140],
#        [    44,  85910],
#        [    61, 122210],
#        [    50,  56870],
#        [    58, 157300],
#        [    55, 137940],
#        [    43, 171820],
#        [    49,  26620],
#        [    51, 116160],
#        [    55, 181500],
#        [    62,  50820],
#        [    38,  70180],
#        [    50,  52030],
#        [    63, 130680],
#        [    52,  78650],
#        [    43,  94380],
#        [    49, 116160],
#        [    62, 173030],
#        [    44,  96800],
#        [    38, 110110],
#        [    40, 174240],
#        [    63, 123420],
#        [    38,  72600],
#        [    40,  64130],
#        [    39, 152460],
#        [    59, 160930],
#        [    43,  87120],
#        [    45,  96800],
#        [    38, 177870],
#        [    42,  50820],
#        [    43, 129470],
#        [    52, 104060],
#        [    41, 135520],
#        [    49,  95590],
#        [    43,  68970],
#        [    40,  96800],
#        [    49,  99220],
#        [    56, 173030],
#        [    45, 180290],
#        [    41,  71390],
#        [    53, 106480],
#        [    59, 125840],
#        [    44,  87120],
#        [    54, 176660],
#        [    38,  60500],
#        [    60, 147620],
#        [    44,  62920],
#        [    38, 117370],
#        [    47,  47190],
#        [    40,  62920],
#        [    51, 162140],
#        [    40, 176660],
#        [    53,  53240],
#        [    55, 108900],
#        [    44,  87120],
#        [    43,  68970],
#        [    61, 114950],
#        [    48, 158510],
#        [    38,  93170],
#        [    39, 174240],
#        [    58, 151250],
#        [    38,  87120],
#        [    51, 108900],
#        [    45, 130680],
#        [    43,  90750],
#        [    40,  89540],
#        [    50, 174240],
#        [    43,  73810],
#        [    46, 160930],
#        [    62,  91960],
#        [    63,  50820],
#        [    42, 128260],
#        [    60,  31460],
#        [    60,  89540],
#        [    41,  85910],
#        [    52, 106480],
#        [    55,  45980],
#        [    53,  43560],
#        [    62, 106480],
#        [    38,  73810],
#        [    40,  84700],
#        [    55,  25410],
#        [    51, 170610],
#        [    40, 112530],
#        [    40,  75020],
#        [    51, 166980],
#        [    44,  95590],
#        [    40,  94380],
#        [    42, 162140],
#        [    52, 107690],
#        [    58,  47190],
#        [    40,  93170],
#        [    38,  68970],
#        [    39,  76230],
#        [    45,  88330],
#        [    46, 135520],
#        [    48,  95590],
#        [    49, 141570],
#        [    61,  45980],
#        [    51,  89540],
#        [    40, 165770],
#        [    40,  95590],
#        [    43,  72600],
#        [    45,  65340],
#        [    54, 162140],
#        [    50, 136730],
#        [    39, 151250],
#        [    41,  60500],
#        [    45,  84700],
#        [    42, 116160],
#        [    41,  60500],
#        [    52, 170610],
#        [    42,  95590],
#        [    42,  90750],
#        [    57, 125840],
#        [    38,  66550],
#        [    48,  38720],
#        [    39,  72600],
#        [    55, 166980],
#        [    56,  99220],
#        [    44,  62920],
#        [    51,  36300],
#        [    51, 158510],
#        [    44,  72600],
#        [    44,  87120],
#        [    45,  90750],
#        [    39, 142780],
#        [    50, 129470],
#        [    41,  61710],
#        [    51, 143990],
#        [    45,  78650],
#        [    43,  78650],
#        [    60,  72600],
#        [    39,  65340],
#        [    61, 174240],
#        [    38,  95590],
#        [    41,  66550],
#        [    42, 147620],
#        [    56, 125840],
#        [    38,  90750],
#        [    41,  78650],
#        [    50,  61710],
#        [    50, 127050],
#        [    44,  76230],
#        [    56,  87120],
#        [    57, 130680],
#        [    42,  93170],
#        [    41,  73810],
#        [    41, 136730],
#        [    40,  90750],
#        [    45, 108900],
#        [    40,  68970],
#        [    39, 119790],
#        [    63,  41140],
#        [    57,  84700],
#        [    44,  87120],
#        [    43,  85910],
#        [    45,  65340],
#        [    46, 156090],
#        [    56,  41140],
#        [    50,  60500],
#        [    45,  95590],
#        [    45, 125840],
#        [    62,  35090],
#        [    61,  56870],
#        [    49, 106480],
#        [    41,  85910],
#        [    57,  31460],
#        [    63,  55660],
#        [    63, 100430],
#        [    42,  88330],
#        [    62, 157300],
#        [    40,  96800],
#        [    49,  38720],
#        [    49,  89540],
#        [    45,  64130],
#        [    44, 105270],
#        [    61,  27830],
#        [    45,  77440],
#        [    51,  39930],
#        [    47, 168190],
#        [    52,  33880],
#        [    60,  39930],
#        [    59,  72600],
#        [    52,  47190],
#        [    42,  85910],
#        [    50,  41140],
#        [    51,  42350],
#        [    51,  39930],
#        [    50,  27830],
#        [    48,  54450],
#        [    63,  50820],
#        [    42,  71390],
#        [    49,  49610],
#        [    54,  27830],
#        [    53,  24200],
#        [    39,  39930],
#        [    52,  43560]])

# %% [markdown]
# #### Step 2: Split the data into training set and testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# #### Step 3: Building a classifier model

# %% [markdown]
# #### i) K Nearest Neighbours (KNN) Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(8)

# %% [markdown]
# #### Training the model

# %%
KNN.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %% [markdown]
# #### Testing the model

# %%
y_pred_KNN = KNN.predict(x_test)

# %% [markdown]
# ### Use some metric to evaluate the KNN classifier

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
confusion_matrix(y_test, y_pred_KNN)
# Out:
# array([[51,  3],
#        [ 9, 17]])

# %%
print("KNN Classifier")
print("**************")
print(f"1. Confusion Matrix:\n{confusion_matrix(y_test, y_pred_KNN)}")
print(f"2. Accuracy Matrix: {accuracy_score(y_test, y_pred_KNN)}")
print(f"3. Precision Score: {precision_score(y_test, y_pred_KNN)}")
print(f"4. Recall Score: {recall_score(y_test, y_pred_KNN)}")
print(f"5. F1 Score: {f1_score(y_test, y_pred_KNN)}")
# Out:
# KNN Classifier
# **************
# 1. Confusion Matrix:
# [[51  3]
#  [ 9 17]]
# 2. Accuracy Matrix: 0.85
# 3. Precision Score: 0.85
# 4. Recall Score: 0.6538461538461539
# 5. F1 Score: 0.7391304347826086

# %% [markdown]
# #### ii) Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()

# %% [markdown]
# ### Training the NB model

# %%
NB.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### Testing the NB model

# %%
y_pred_NB = NB.predict(x_test)

# %%
print("NB Classifier")
print("**************")
print(f"1. Confusion Matrix:\n{confusion_matrix(y_test, y_pred_NB)}")
print(f"2. Accuracy Matrix: {accuracy_score(y_test, y_pred_NB)}")
print(f"3. Precision Score: {precision_score(y_test, y_pred_NB)}")
print(f"4. Recall Score: {recall_score(y_test, y_pred_NB)}")
print(f"5. F1 Score: {f1_score(y_test, y_pred_NB)}")
# Out:
# NB Classifier
# **************
# 1. Confusion Matrix:
# [[51  3]
#  [ 7 19]]
# 2. Accuracy Matrix: 0.875
# 3. Precision Score: 0.8636363636363636
# 4. Recall Score: 0.7307692307692307
# 5. F1 Score: 0.7916666666666666

# %% [markdown]
# #### iii) Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier(criterion="entropy", max_depth=4)

# %% [markdown]
# ### Training the DT model

# %%
DT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# ### Testing the DT model

# %%
y_pred_DT = DT.predict(x_test)

# %%
print("DT Classifier")
print("**************")
print(f"1. Confusion Matrix:\n{confusion_matrix(y_test, y_pred_DT)}")
print(f"2. Accuracy Matrix: {accuracy_score(y_test, y_pred_DT)}")
print(f"3. Precision Score: {precision_score(y_test, y_pred_DT)}")
print(f"4. Recall Score: {recall_score(y_test, y_pred_DT)}")
print(f"5. F1 Score: {f1_score(y_test, y_pred_DT)}")
# Out:
# DT Classifier
# **************
# 1. Confusion Matrix:
# [[51  3]
#  [ 6 20]]
# 2. Accuracy Matrix: 0.8875
# 3. Precision Score: 0.8695652173913043
# 4. Recall Score: 0.7692307692307693
# 5. F1 Score: 0.8163265306122449

# %% [markdown]
# #### iv) Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(1000, criterion="entropy")
RF.fit(x_train, y_train)
y_pred_RF = RF.predict(x_test)

# %%
print("RF Classifier")
print("**************")
print(f"1. Confusion Matrix:\n{confusion_matrix(y_test, y_pred_RF)}")
print(f"2. Accuracy Matrix: {accuracy_score(y_test, y_pred_RF)}")
print(f"3. Precision Score: {precision_score(y_test, y_pred_RF)}")
print(f"4. Recall Score: {recall_score(y_test, y_pred_RF)}")
print(f"5. F1 Score: {f1_score(y_test, y_pred_RF)}")
# Out:
# RF Classifier
# **************
# 1. Confusion Matrix:
# [[52  2]
#  [ 5 21]]
# 2. Accuracy Matrix: 0.9125
# 3. Precision Score: 0.9130434782608695
# 4. Recall Score: 0.8076923076923077
# 5. F1 Score: 0.8571428571428571

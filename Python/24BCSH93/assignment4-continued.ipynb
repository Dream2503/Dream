# %% [markdown]
# Q1. Write a Python program to remove duplicates from a list

# %%
lst = list(eval(input("Enter a list of numbers(comma-separated): ")))
res = []

for element in lst:
    if element not in res:
        res.append(element)

print("The list with unique elements are:", res)
# Out:
# Enter a list of numbers(comma-separated):  2, 5, 0, 3, 8, 6, 6, 0
# The list with unique elements are: [2, 5, 0, 3, 8, 6]

# %% [markdown]
# Q2. Write a Python program to find the second largest number in a list.

# %%
lst = list(eval(input("Enter a list of numbers(comma-separated): ")))
max = res = lst[0]

for element in lst[1:]:
    if element > max:
        res = max
        max = element
    elif element > res:
        res = element

if res == max:
    print("There is no second maximum element in the list")
else:
    print("The second maximum element in the list is:", res)
# Out:
# Enter a list of numbers(comma-separated):  2, 5, 0, 3, 8, 6, 6, 0
# The second maximum element in the list is: 6

# %% [markdown]
# Q3. Write a Python program to sort a list of elements using the bubble sort algorithm.

# %%
lst = list(eval(input("Enter a list of numbers(comma-separated): ")))

for i in range(len(lst) - 1):
    for j in range(len(lst) - i - 1):
        if lst[j] > lst[j + 1]:
            lst[j], lst[j + 1] = lst[j + 1], lst[j]

print("The list after bubble sort is:", lst)
# Out:
# Enter a list of numbers(comma-separated):  2, 5, 0, 3, 8, 6, 6, 0
# The list after bubble sort is: [0, 0, 2, 3, 5, 6, 6, 8]

# %% [markdown]
# Q4. Write a Python program to find the common elements between two lists.

# %%
lst1 = list(eval(input("Enter the first list of numbers(comma-separated): ")))
lst2 = list(eval(input("Enter the second list of numbers(comma-separated): ")))
res = [element for element in lst1 if element in lst2]
print("The intersection of the two list are:", res)
# Out:
# Enter the first list of numbers(comma-separated):  2, 5, 0, 3
# Enter the second list of numbers(comma-separated):  8, 6, 6, 0
# The intersection of the two list are: [0]

# %% [markdown]
# Q5. Write a Python program to count the frequency of each element in a list.

# %%
lst = list(eval(input("Enter a list of numbers(comma-separated): ")))
seen = []
print("The frequency of all the element in the list is:", end=" ")

for element in lst:
    if element not in seen:
        print(element, "->", lst.count(element), sep="", end=" ")
        seen.append(element)
# Out:
# Enter a list of numbers(comma-separated):  2, 5, 0, 3, 8, 6, 6, 0
# The frequency of all the element in the list is: 2->1 5->1 0->2 3->1 8->1 6->2

# %% [markdown]
# Q6. Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings

# %%
lst = list(eval(input("Enter a list of strings(comma-separated): ")))
res = [element for element in lst if len(element) >= 2 and element[0] == element[-1]]
print("The resultant list is:", res)
# Out:
# Enter a list of strings(comma-separated):  "aba", "xyz", "aa", "x", "bbb", "abca", "cc"
# The resultant list is: ['aba', 'aa', 'bbb', 'abca', 'cc']

# %% [markdown]
# Q7. Write a Program that get two lists as input and check if they have at least one common member

# %%
lst1 = list(eval(input("Enter the first list of numbers(comma-separated): ")))
lst2 = list(eval(input("Enter the second list of numbers(comma-separated): ")))

for element in lst1:
    if element in lst2:
        print("They have one common element ie:", element)
        break
else:
    print("They have no common element")
# Out:
# Enter the first list of numbers(comma-separated):  2, 5, 0, 3
# Enter the second list of numbers(comma-separated):  8, 6, 6, 0
# They have one common element ie: 0

# %% [markdown]
# Q8. Write a Python program to print a specified list after removing the 0th, 4th and 5th elements.

# %%
lst = list(eval(input("Enter a list of numbers(comma-separated): ")))

if len(lst) > 5:
    for idx in (5, 4, 0):
        lst.pop(idx)

    print("The resultant list is:", lst)
else:
    print("There must be atleast 6 element in the list")
# Out:
# Enter a list of numbers(comma-separated):  2, 5, 0, 3, 8, 6, 6, 0
# The resultant list is: [5, 0, 3, 6, 0]

# %% [markdown]
# Q9. Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30

# %%
res = [element ** 2 for element in range(1, 6)] + [element ** 2 for element in range(25, 31)]
print("The resultant list is:", res)
# Out:
# The resultant list is: [1, 4, 9, 16, 25, 625, 676, 729, 784, 841, 900]

# %% [markdown]
# Q10. Write a Python Program to print all Possible Combinations from the three Digits

# %%
lst = input("Enter the 3 digits: ")
print("The the combination of the 3 digits,", lst, "are:")

for first in lst:
    for middle in lst:
        for last in lst:
            print(first, middle, last, sep="", end=" ")
        print()
# Out:
# Enter the 3 digits:  729
# The the combination of the 3 digits, 729 are:
# 777 772 779
# 727 722 729
# 797 792 799
# 277 272 279
# 227 222 229
# 297 292 299
# 977 972 979
# 927 922 929
# 997 992 999

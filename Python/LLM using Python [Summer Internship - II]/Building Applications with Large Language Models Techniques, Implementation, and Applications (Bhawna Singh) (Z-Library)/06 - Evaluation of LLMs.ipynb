# %% [markdown]
# # Advanced Capabilities: Language Translation

# %%
import evaluate

meteor = evaluate.load('meteor')
candidate = ["Every student will follow the teacher's instructions"]
reference = ["It is mandatory for all students to follow their teacher's instructions"]
results = meteor.compute(predictions=candidate, references=reference)

print(results)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# [nltk_data] Downloading package wordnet to /home/dream/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/dream/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/dream/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# {'meteor': np.float64(0.38448275862068976)}

# %%
bleu = evaluate.load('bleu')
candidate = ["Every student will follow the teacher's instructions"]
reference = ["It is mandatory for all students to follow their teacher's instructions"]
results = bleu.compute(predictions=candidate, references=reference)

print(results)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# {'bleu': 0.0, 'precisions': [0.42857142857142855, 0.16666666666666666, 0.0, 0.0], 'brevity_penalty': 0.5647181220077593, 'length_ratio': 0.6363636363636364, 'translation_length': 7, 'reference_length': 11}

# %% [markdown]
# # Advanced Capabilities: Text Summarization

# %%
import evaluate

meteor = evaluate.load('rouge')
candidate = ["Every student will follow the teacher's instructions"]
reference = ["It is mandatory for all students to follow their teacher's instructions"]
results = meteor.compute(predictions=candidate, references=reference)

print(results)
# Out:
# {'rouge1': np.float64(0.4), 'rouge2': np.float64(0.2222222222222222), 'rougeL': np.float64(0.4), 'rougeLsum': np.float64(0.4)}
